# %%
# %matplotlib inline

import gmfunc as gm
# Out:
# :0: FutureWarning: IPython widgets are experimental and may change in the future.

# %% [markdown]
# # Galaxy Merging Simulation

# %% [markdown]
# This is a simulation of what happens to the stars orbiting a galaxy $M$ when another galaxy $S$ passes by it in space. I looked into three main situations: retrograde passage, direct passage, and direct passage with a heavy mass disruptor.
#
# The units used are:
#
# -time is in $10^{8}$ years
#
# -mass is in solar units(mass of our sun)
#
# -distance is in kiloparsecs
#
# The Galaxy of focus $M$ is colored red
#
# The disrupting galaxy $S$ is colored green
#
# The stars orbiting $M$ are colored blue
#
# The differential whioch dictate the movement of the stars and galaxy S are
#
# $$ \ddot{\mathbf{r}} = -\gamma \left\{ \frac{M}{r^3}\mathbf{r} -\frac{S}{\rho^3}\boldsymbol{\rho} + \frac{S}{R^3}\boldsymbol\Re \right\} $$
#
# $$ \ddot{\boldsymbol\Re} = -\gamma \frac{M+S}{R^3}\boldsymbol\Re$$
#
# where
#
# * $\gamma$ is the Gravitational constant.
# * $M$ is the central mass of the main galaxy and $S$ is the central mass of the disrupting galaxy
# * $\mathbf{r}$ is the radius vector from mass $M$ to massless point particle $m$, representing a single (massless) star in the outer disk of the main galaxy.
# * $\boldsymbol\Re$ is the radius vector from $M$ to $S$
# * $\boldsymbol{\rho} = \boldsymbol{\Re} - \boldsymbol{r}$

# %% [markdown]
# ##Retrograde Passage

# %% [markdown]
# Retrograde passage is when the orbital velocities of the stars orbiting $M$ are counter to the direction of the orbit of $S$ about $M$
#
# -the $1st$, $3rd$, and $5th$ cells contains an interactive plot from $t=0$ to $t=20$
#
# -the $2nd$, $4th$, and $6th$ cell contains a snapshot at $t=5,6,7,8,9,10,11,12$

# %%
gm.interact_1()

# %%
gm.subplot_1(5,75)

# %%
gm.interact_2()

# %%
gm.subplot_2(5,75)

# %%
gm.interact_3()

# %%
gm.subplot_3(5,75)

# %% [markdown]
# ##Direct Passage

# %% [markdown]
# Counter to retrograde passage, during a direct passge the orbital velocities of the stars is aligned with the direction that galaxy $S$ orbits $M$
#
# -the following cell contains an interactive plot from $t=0$ to $t=20$

# %%
gm.dinteract_1()

# %% [markdown]
# ##Direct Passage with Heavy Mass Disruptor

# %% [markdown]
# The heavy mass disruptor component to this direct passage means that the mass of galaxy $S$ is larger than that of galaxy $M$
#
# -in this case, galaxy $S$ has a mass $3$ times larger than galaxy $M$

# %%
gm.hinteract_1()
